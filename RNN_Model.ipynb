# %%
from First_Dataset import First_Dataset

# %%
max_words = 5000
max_len = 50

# %%
dataset = First_Dataset()
dataset.preprocess()
dataset.split()
dataset.encode_labels()
dataset.embed_tokens(max_words,max_len)
Training_pad, Validation_pad, Testing_pad, Y_train, Y_val, Y_test = dataset.getData()

# %%
from RNN import RNN

# %%
model = RNN(max_words, max_len)

# %%
# model.plot_model()

# %%
model.fit(Training_pad,Y_train, Validation_pad, Y_val)
# Out:
# Epoch 1/50
# 140/140 [==============================] - 3s 9ms/step - loss: 1.8884 - accuracy: 0.7354 - val_loss: 0.5938 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 2/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.5845 - accuracy: 0.7436 - val_loss: 0.6032 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 3/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.5318 - accuracy: 0.7747 - val_loss: 0.5966 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 4/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.2162 - accuracy: 0.9410 - val_loss: 0.6125 - val_accuracy: 0.7621 - lr: 5.0000e-04
# Epoch 5/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.1004 - accuracy: 0.9826 - val_loss: 0.6488 - val_accuracy: 0.7764 - lr: 5.0000e-04
# Epoch 6/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.0640 - accuracy: 0.9908 - val_loss: 0.6414 - val_accuracy: 0.8032 - lr: 2.5000e-04
# Epoch 7/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.0505 - accuracy: 0.9946 - val_loss: 0.6386 - val_accuracy: 0.8193 - lr: 2.5000e-04
# Epoch 8/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.0413 - accuracy: 0.9960 - val_loss: 0.6838 - val_accuracy: 0.8104 - lr: 1.2500e-04
# Epoch 9/50
# 140/140 [==============================] - 1s 8ms/step - loss: 0.0355 - accuracy: 0.9978 - val_loss: 0.7095 - val_accuracy: 0.7943 - lr: 1.2500e-04
# Epoch 10/50
# 140/140 [==============================] - 1s 8ms/step - loss: 0.0341 - accuracy: 0.9978 - val_loss: 0.6936 - val_accuracy: 0.8068 - lr: 6.2500e-05
# Epoch 11/50
# 140/140 [==============================] - 1s 8ms/step - loss: 0.0327 - accuracy: 0.9969 - val_loss: 0.6974 - val_accuracy: 0.8014 - lr: 6.2500e-05
# Epoch 12/50
# 140/140 [==============================] - 1s 8ms/step - loss: 0.0296 - accuracy: 0.9978 - val_loss: 0.6974 - val_accuracy: 0.8086 - lr: 3.1250e-05

# %%
model.plot_history()

# %%
model.test(Testing_pad, Y_test)
# Out:
# 18/18 [==============================] - 0s 3ms/step - loss: 0.5422 - accuracy: 0.8446
