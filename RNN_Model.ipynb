# %%
# %load_ext autoreload
# %autoreload 2

# %%
from First_Dataset import First_Dataset
# Out:
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
max_words = 5000
max_len = 50

# %%
dataset = First_Dataset()
dataset.preprocess()
dataset.encode_labels()
dataset.embed_tokens(max_words,max_len)
dataset.split()
Training_pad, Validation_pad, Testing_pad, Y_train, Y_val, Y_test = dataset.getData()

# %%
from RNN import RNN

# %%
model = RNN(max_words, max_len)
# Out:
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# model.plot_model()

# %%
model.fit(Training_pad,Y_train, Validation_pad, Y_val)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 140/140 [==============================] - 3s 9ms/step - loss: 1.8144 - accuracy: 0.7870 - val_loss: 0.7084 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 2/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.2671 - accuracy: 0.9397 - val_loss: 0.5645 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 3/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.1485 - accuracy: 0.9714 - val_loss: 0.5141 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 4/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.1014 - accuracy: 0.9844 - val_loss: 0.3472 - val_accuracy: 0.8927 - lr: 0.0010
# Epoch 5/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.0927 - accuracy: 0.9861 - val_loss: 0.4831 - val_accuracy: 0.8927 - lr: 0.0010
# Epoch 6/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0758 - accuracy: 0.9897 - val_loss: 0.4178 - val_accuracy: 0.8927 - lr: 0.0010
# Epoch 7/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.0479 - accuracy: 0.9942 - val_loss: 0.4783 - val_accuracy: 0.9016 - lr: 5.0000e-04
# Epoch 8/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0361 - accuracy: 0.9969 - val_loss: 0.6125 - val_accuracy: 0.8837 - lr: 5.0000e-04
# Epoch 9/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0284 - accuracy: 0.9969 - val_loss: 0.5353 - val_accuracy: 0.8927 - lr: 2.5000e-04
# Epoch 10/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0313 - accuracy: 0.9969 - val_loss: 0.4984 - val_accuracy: 0.8980 - lr: 2.5000e-04
# Epoch 11/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.0226 - accuracy: 0.9975 - val_loss: 0.5320 - val_accuracy: 0.8945 - lr: 1.2500e-04
# Epoch 12/50
# 140/140 [==============================] - 1s 7ms/step - loss: 0.0210 - accuracy: 0.9987 - val_loss: 0.5028 - val_accuracy: 0.8962 - lr: 1.2500e-04

# %%
model.plot_history()

# %%
model.test(Testing_pad, Y_test)
# Out:
# 18/18 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.76      0.80       143
#            1       0.92      0.95      0.94       417
#
#     accuracy                           0.90       560
#    macro avg       0.88      0.86      0.87       560
# weighted avg       0.90      0.90      0.90       560

# %%
from Second_Dataset import Second_Dataset

# %%
dataset2 = Second_Dataset()
dataset2.preprocess()
dataset2.encode_labels()
dataset2.embed_tokens(max_words,max_len)
dataset2.split()
Training_pad2, Validation_pad2, Testing_pad2, Y_train2, Y_val2, Y_test2 = dataset2.getData()

# %%
model2 = RNN(max_words, max_len)

# %%
model2.fit(Training_pad2,Y_train2, Validation_pad2, Y_val2)
# Out:
# Epoch 1/50
# 147/147 [==============================] - 3s 8ms/step - loss: 1.8467 - accuracy: 0.6091 - val_loss: 0.6991 - val_accuracy: 0.6137 - lr: 0.0010
# Epoch 2/50
# 147/147 [==============================] - 1s 7ms/step - loss: 0.6811 - accuracy: 0.6135 - val_loss: 0.6781 - val_accuracy: 0.6137 - lr: 0.0010
# Epoch 3/50
# 147/147 [==============================] - 1s 7ms/step - loss: 0.6917 - accuracy: 0.6129 - val_loss: 0.6919 - val_accuracy: 0.6137 - lr: 0.0010
# Epoch 4/50
# 147/147 [==============================] - 1s 7ms/step - loss: 0.6425 - accuracy: 0.6800 - val_loss: 0.6933 - val_accuracy: 0.6120 - lr: 0.0010
# Epoch 5/50
# 147/147 [==============================] - 1s 6ms/step - loss: 0.3977 - accuracy: 0.8468 - val_loss: 0.7595 - val_accuracy: 0.6154 - lr: 5.0000e-04
# Epoch 6/50
# 147/147 [==============================] - 1s 6ms/step - loss: 0.2576 - accuracy: 0.9107 - val_loss: 1.1521 - val_accuracy: 0.5761 - lr: 5.0000e-04
# Epoch 7/50
# 147/147 [==============================] - 1s 6ms/step - loss: 0.1542 - accuracy: 0.9543 - val_loss: 1.4969 - val_accuracy: 0.5726 - lr: 2.5000e-04
# Epoch 8/50
# 147/147 [==============================] - 1s 6ms/step - loss: 0.1252 - accuracy: 0.9660 - val_loss: 1.4435 - val_accuracy: 0.6120 - lr: 2.5000e-04
# Epoch 9/50
# 147/147 [==============================] - 1s 7ms/step - loss: 0.1012 - accuracy: 0.9742 - val_loss: 1.5043 - val_accuracy: 0.6103 - lr: 1.2500e-04
# Epoch 10/50
# 147/147 [==============================] - 1s 7ms/step - loss: 0.0947 - accuracy: 0.9761 - val_loss: 1.6152 - val_accuracy: 0.5915 - lr: 1.2500e-04

# %%
model2.plot_history()

# %%
model2.test(Testing_pad2, Y_test2)
# Out:
# 19/19 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.51      0.43      0.47       226
#            1       0.67      0.73      0.70       360
#
#     accuracy                           0.62       586
#    macro avg       0.59      0.58      0.58       586
# weighted avg       0.61      0.62      0.61       586
