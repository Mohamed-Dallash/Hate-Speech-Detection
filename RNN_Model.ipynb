# %%
# %load_ext autoreload
# %autoreload 2

# %%
from First_Dataset import First_Dataset
# Out:
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\moham\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
max_words = 5000
max_len = 50

# %%
dataset = First_Dataset()
dataset.preprocess()
dataset.encode_labels()
dataset.embed_tokens(max_words,max_len)
dataset.split()
Training_pad, Validation_pad, Testing_pad, Y_train, Y_val, Y_test = dataset.getData()

# %%
from RNN import RNN

# %%
model = RNN(max_words, max_len)
# Out:
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# model.plot_model()

# %%
model.fit(Training_pad,Y_train, Validation_pad, Y_val)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From d:\Development\Hate-Speech-Detection\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 140/140 [==============================] - 3s 9ms/step - loss: 1.8417 - accuracy: 0.7919 - val_loss: 0.6901 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 2/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.2239 - accuracy: 0.9446 - val_loss: 0.5713 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 3/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.1103 - accuracy: 0.9799 - val_loss: 0.4673 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 4/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0800 - accuracy: 0.9875 - val_loss: 0.3812 - val_accuracy: 0.8712 - lr: 0.0010
# Epoch 5/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0766 - accuracy: 0.9875 - val_loss: 0.4158 - val_accuracy: 0.8909 - lr: 0.0010
# Epoch 6/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0665 - accuracy: 0.9920 - val_loss: 0.5056 - val_accuracy: 0.8909 - lr: 0.0010
# Epoch 7/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0410 - accuracy: 0.9953 - val_loss: 0.4781 - val_accuracy: 0.8998 - lr: 5.0000e-04
# Epoch 8/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0352 - accuracy: 0.9962 - val_loss: 0.5874 - val_accuracy: 0.8873 - lr: 5.0000e-04
# Epoch 9/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0254 - accuracy: 0.9980 - val_loss: 0.5304 - val_accuracy: 0.8945 - lr: 2.5000e-04
# Epoch 10/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0253 - accuracy: 0.9978 - val_loss: 0.5383 - val_accuracy: 0.8909 - lr: 2.5000e-04
# Epoch 11/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0217 - accuracy: 0.9989 - val_loss: 0.5624 - val_accuracy: 0.8927 - lr: 1.2500e-04
# Epoch 12/50
# 140/140 [==============================] - 1s 6ms/step - loss: 0.0190 - accuracy: 0.9987 - val_loss: 0.5866 - val_accuracy: 0.8873 - lr: 1.2500e-04

# %%
model.plot_history()

# %%
model.test(Testing_pad, Y_test)
# Out:
# 18/18 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.81       143
#            1       0.94      0.93      0.93       417
#
#     accuracy                           0.90       560
#    macro avg       0.87      0.88      0.87       560
# weighted avg       0.90      0.90      0.90       560
